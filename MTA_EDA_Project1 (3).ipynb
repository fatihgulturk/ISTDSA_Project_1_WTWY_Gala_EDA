# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %%
df0 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_210306.txt')
df0 = pd.DataFrame(df0)


df1 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_210313.txt')
df1 = pd.DataFrame(df1)


df2 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_210320.txt')
df2 = pd.DataFrame(df2)


df3 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_210327.txt')
df3 = pd.DataFrame(df3)


df4 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_210403.txt')
df4 = pd.DataFrame(df4)


df5 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_210410.txt')
df5 = pd.DataFrame(df5)


df6 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_210417.txt')
df6 = pd.DataFrame(df6)


df7 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_210424.txt')
df7 = pd.DataFrame(df7)


df8 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_210501.txt')
df8 = pd.DataFrame(df8)


df9 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_210508.txt')
df9 = pd.DataFrame(df9)


df10 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_210515.txt')
df10 = pd.DataFrame(df10)


df11 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_210522.txt')
df11 = pd.DataFrame(df11)


df12 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_210529.txt')
df12 = pd.DataFrame(df12)

df = pd.concat([df0, df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12], ignore_index = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2717757 entries, 0 to 2717756
# Data columns (total 11 columns):
#  #   Column                                                                Dtype
# ---  ------                                                                -----
#  0   C/A                                                                   object
#  1   UNIT                                                                  object
#  2   SCP                                                                   object
#  3   STATION                                                               object
#  4   LINENAME                                                              object
#  5   DIVISION                                                              object
#  6   DATE                                                                  object
#  7   TIME                                                                  object
# ...

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/27/2021  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/27/2021  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/27/2021  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/27/2021  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/27/2021  19:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7537255
# 1  REGULAR  7537260
# 2  REGULAR  7537285
# 3  REGULAR  7537354
# 4  REGULAR  7537501
#
#    EXITS
# 0                                            2570434
# 1                                            2570445
# 2                                            2570500
# 3                                            2570546
# 4                                            2570582

# %%
df.tail()
# Out:
#            C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 2717752  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/28/2021
# 2717753  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/28/2021
# 2717754  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/28/2021
# 2717755  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/28/2021
# 2717756  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/28/2021
#
#              TIME     DESC  ENTRIES  \
# 2717752  08:20:35  REGULAR     5554
# 2717753  09:00:00  REGULAR     5554
# 2717754  13:00:00  REGULAR     5554
# 2717755  17:00:00  REGULAR     5554
# 2717756  21:00:00  REGULAR     5554
#
#          EXITS
# 2717752                                                577
# 2717753                                                577
# 2717754                                                577
# 2717755                                                577
# ...

# %%
print(df.isnull().sum())
# Out:
# C/A                                                                     0
# UNIT                                                                    0
# SCP                                                                     0
# STATION                                                                 0
# LINENAME                                                                0
# DIVISION                                                                0
# DATE                                                                    0
# TIME                                                                    0
# DESC                                                                    0
# ENTRIES                                                                 0
# EXITS                                                                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
df.rename(columns={'EXITS                                                               ':'EXITS'}, inplace=True)

# %%
df['TIMESTAMP'] = pd.to_datetime(df['DATE'] + ' ' + df['TIME'])

# %%
print(type(df.TIMESTAMP[0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2717757 entries, 0 to 2717756
# Data columns (total 12 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   C/A        object
#  1   UNIT       object
#  2   SCP        object
#  3   STATION    object
#  4   LINENAME   object
#  5   DIVISION   object
#  6   DATE       object
#  7   TIME       object
#  8   DESC       object
#  9   ENTRIES    int64
#  10  EXITS      int64
#  11  TIMESTAMP  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 248.8+ MB

# %%
df['WEEKDAYS'] = pd.to_datetime(df['DATE']).dt.day_name()
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/27/2021  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/27/2021  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/27/2021  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/27/2021  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/27/2021  19:00:00
#
#       DESC  ENTRIES    EXITS           TIMESTAMP  WEEKDAYS
# 0  REGULAR  7537255  2570434 2021-02-27 03:00:00  Saturday
# 1  REGULAR  7537260  2570445 2021-02-27 07:00:00  Saturday
# 2  REGULAR  7537285  2570500 2021-02-27 11:00:00  Saturday
# 3  REGULAR  7537354  2570546 2021-02-27 15:00:00  Saturday
# 4  REGULAR  7537501  2570582 2021-02-27 19:00:00  Saturday

# %%
df['TURNSTILE'] = df['C/A'] + df['UNIT'] + df['SCP']

# %%
#df['ID'] = df['TURNSTILE'] + df['DATE'] + df['TIME']

# %%
df.head(5)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/27/2021  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/27/2021  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/27/2021  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/27/2021  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/27/2021  19:00:00
#
#       DESC  ENTRIES    EXITS           TIMESTAMP  WEEKDAYS         TURNSTILE
# 0  REGULAR  7537255  2570434 2021-02-27 03:00:00  Saturday  A002R05102-00-00
# 1  REGULAR  7537260  2570445 2021-02-27 07:00:00  Saturday  A002R05102-00-00
# 2  REGULAR  7537285  2570500 2021-02-27 11:00:00  Saturday  A002R05102-00-00
# 3  REGULAR  7537354  2570546 2021-02-27 15:00:00  Saturday  A002R05102-00-00
# 4  REGULAR  7537501  2570582 2021-02-27 19:00:00  Saturday  A002R05102-00-00

# %%
df.shape
# Out:
# (2717757, 14)

# %%
df.sort_values(["STATION","TURNSTILE","TIMESTAMP"], inplace=True, ascending=True)
df.drop_duplicates(subset=["STATION","TURNSTILE","TIMESTAMP"], inplace=True)

# %%
df.shape
# Out:
# (2717678, 14)

# %%
df.head(5)
# Out:
#          C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 32697  H007A  R248  02-00-00    1 AV        L      BMT  02/27/2021  03:00:00
# 32698  H007A  R248  02-00-00    1 AV        L      BMT  02/27/2021  07:00:00
# 32699  H007A  R248  02-00-00    1 AV        L      BMT  02/27/2021  11:00:00
# 32700  H007A  R248  02-00-00    1 AV        L      BMT  02/27/2021  15:00:00
# 32701  H007A  R248  02-00-00    1 AV        L      BMT  02/27/2021  19:00:00
#
#           DESC  ENTRIES  EXITS           TIMESTAMP  WEEKDAYS  \
# 32697  REGULAR   209543  33537 2021-02-27 03:00:00  Saturday
# 32698  REGULAR   209550  33539 2021-02-27 07:00:00  Saturday
# 32699  REGULAR   209619  33548 2021-02-27 11:00:00  Saturday
# 32700  REGULAR   209758  33568 2021-02-27 15:00:00  Saturday
# 32701  REGULAR   209890  33580 2021-02-27 19:00:00  Saturday
#
#                TURNSTILE
# 32697  H007AR24802-00-00
# 32698  H007AR24802-00-00
# 32699  H007AR24802-00-00
# 32700  H007AR24802-00-00
# ...

# %%
df['NET_ENTRIES'] = df.ENTRIES.shift(-1) - df.ENTRIES
df['NET_EXITS'] = df.EXITS.shift(-1) - df.EXITS

# %%
# Drop columns that I don't need: Division, Date, Time, DESC, Entries, and Exits...
df = df.drop(['C/A','UNIT','SCP','DIVISION','LINENAME', 'DESC', 'ENTRIES', 'EXITS'], 1)

# %%
df.head()
# Out:
#       STATION        DATE      TIME           TIMESTAMP  WEEKDAYS  \
# 32697    1 AV  02/27/2021  03:00:00 2021-02-27 03:00:00  Saturday
# 32698    1 AV  02/27/2021  07:00:00 2021-02-27 07:00:00  Saturday
# 32699    1 AV  02/27/2021  11:00:00 2021-02-27 11:00:00  Saturday
# 32700    1 AV  02/27/2021  15:00:00 2021-02-27 15:00:00  Saturday
# 32701    1 AV  02/27/2021  19:00:00 2021-02-27 19:00:00  Saturday
#
#                TURNSTILE  NET_ENTRIES  NET_EXITS
# 32697  H007AR24802-00-00          7.0        2.0
# 32698  H007AR24802-00-00         69.0        9.0
# 32699  H007AR24802-00-00        139.0       20.0
# 32700  H007AR24802-00-00        132.0       12.0
# 32701  H007AR24802-00-00         66.0       18.0

# %%
df.tail()
# Out:
#            STATION        DATE      TIME           TIMESTAMP WEEKDAYS  \
# 2692371  ZEREGA AV  05/28/2021  05:00:00 2021-05-28 05:00:00   Friday
# 2692372  ZEREGA AV  05/28/2021  09:00:00 2021-05-28 09:00:00   Friday
# 2692373  ZEREGA AV  05/28/2021  13:00:00 2021-05-28 13:00:00   Friday
# 2692374  ZEREGA AV  05/28/2021  17:00:00 2021-05-28 17:00:00   Friday
# 2692375  ZEREGA AV  05/28/2021  21:00:00 2021-05-28 21:00:00   Friday
#
#                 TURNSTILE  NET_ENTRIES  NET_EXITS
# 2692371  R419R32600-05-01          0.0        0.0
# 2692372  R419R32600-05-01          0.0        0.0
# 2692373  R419R32600-05-01          0.0        0.0
# 2692374  R419R32600-05-01          0.0        0.0
# 2692375  R419R32600-05-01          NaN        NaN

# %%
df.sample(10, random_state = 43)
# Out:
#                  STATION        DATE      TIME           TIMESTAMP  WEEKDAYS  \
# 2236125            86 ST  05/11/2021  01:00:00 2021-05-11 01:00:00   Tuesday
# 1847945       JACKSON AV  04/29/2021  17:00:00 2021-04-29 17:00:00  Thursday
# 424448          8 ST-NYU  03/16/2021  16:00:00 2021-03-16 16:00:00   Tuesday
# 1668154        CHURCH AV  04/18/2021  09:00:00 2021-04-18 09:00:00    Sunday
# 845139      CORTLANDT ST  03/28/2021  05:00:00 2021-03-28 05:00:00    Sunday
# 610774   METS-WILLETS PT  03/15/2021  21:00:00 2021-03-15 21:00:00    Monday
# 2589581  LEXINGTON AV/53  05/27/2021  04:00:00 2021-05-27 04:00:00  Thursday
# 111001          AVENUE X  03/04/2021  03:00:00 2021-03-04 03:00:00  Thursday
# 1343288            75 AV  04/10/2021  16:00:00 2021-04-10 16:00:00  Saturday
# 1560150  BEDFORD-NOSTRAN  04/20/2021  00:00:00 2021-04-20 00:00:00   Tuesday
#
#                  TURNSTILE  NET_ENTRIES  NET_EXITS
# 2236125   R165R16701-00-02          0.0        2.0
# ...

# %%
df = df[(df.NET_ENTRIES > 0) & (df.NET_ENTRIES < 10000) & 
                (df.NET_EXITS > 0) & (df.NET_EXITS < 10000)]

# %%
df.shape
# Out:
# (2102644, 8)

# %%
df.sample(10, random_state = 43)
# Out:
#                  STATION        DATE      TIME           TIMESTAMP   WEEKDAYS  \
# 1541486  BEDFORD PK BLVD  04/22/2021  13:00:00 2021-04-22 13:00:00   Thursday
# 1843760           176 ST  04/28/2021  04:00:00 2021-04-28 04:00:00  Wednesday
# 1665607  CROWN HTS-UTICA  04/21/2021  00:00:00 2021-04-21 00:00:00  Wednesday
# 1713641         GATES AV  04/30/2021  17:00:00 2021-04-30 17:00:00     Friday
# 876978      CLEVELAND ST  04/01/2021  01:00:00 2021-04-01 01:00:00   Thursday
# 404251     FLUSHING-MAIN  03/08/2021  19:00:00 2021-03-08 19:00:00     Monday
# 1170083  THIRTY THIRD ST  04/04/2021  07:44:32 2021-04-04 07:44:32     Sunday
# 373110             51 ST  03/08/2021  07:00:00 2021-03-08 07:00:00     Monday
# 1224656       CYPRESS AV  04/03/2021  13:00:00 2021-04-03 13:00:00   Saturday
# 2121474  CONEY IS-STILLW  05/14/2021  13:00:00 2021-05-14 13:00:00     Friday
#
#                  TURNSTILE  NET_ENTRIES  NET_EXITS
# 1541486   N222R15600-00-01         81.0      146.0
# ...

# %%
df["TRAFFIC"] = df["NET_ENTRIES"] + df["NET_EXITS"]

# %%
df.head()
# Out:
#       STATION        DATE      TIME           TIMESTAMP  WEEKDAYS  \
# 32697    1 AV  02/27/2021  03:00:00 2021-02-27 03:00:00  Saturday
# 32698    1 AV  02/27/2021  07:00:00 2021-02-27 07:00:00  Saturday
# 32699    1 AV  02/27/2021  11:00:00 2021-02-27 11:00:00  Saturday
# 32700    1 AV  02/27/2021  15:00:00 2021-02-27 15:00:00  Saturday
# 32701    1 AV  02/27/2021  19:00:00 2021-02-27 19:00:00  Saturday
#
#                TURNSTILE  NET_ENTRIES  NET_EXITS  TRAFFIC
# 32697  H007AR24802-00-00          7.0        2.0      9.0
# 32698  H007AR24802-00-00         69.0        9.0     78.0
# 32699  H007AR24802-00-00        139.0       20.0    159.0
# 32700  H007AR24802-00-00        132.0       12.0    144.0
# 32701  H007AR24802-00-00         66.0       18.0     84.0

# %%
df.describe()
# Out:
#         NET_ENTRIES     NET_EXITS       TRAFFIC
# count  2.102644e+06  2.102644e+06  2.102644e+06
# mean   6.649508e+01  7.105395e+01  1.375490e+02
# std    8.287307e+01  9.794830e+01  1.482652e+02
# min    1.000000e+00  1.000000e+00  2.000000e+00
# 25%    1.100000e+01  1.200000e+01  3.300000e+01
# 50%    3.700000e+01  3.600000e+01  9.000000e+01
# 75%    9.100000e+01  9.100000e+01  1.920000e+02
# max    9.249000e+03  9.885000e+03  1.260100e+04

# %%
df['WEEKDAYS_INDEX'] = pd.to_datetime(df['DATE']).dt.weekday
df.head()
# Out:
#       STATION        DATE      TIME           TIMESTAMP  WEEKDAYS  \
# 32697    1 AV  02/27/2021  03:00:00 2021-02-27 03:00:00  Saturday
# 32698    1 AV  02/27/2021  07:00:00 2021-02-27 07:00:00  Saturday
# 32699    1 AV  02/27/2021  11:00:00 2021-02-27 11:00:00  Saturday
# 32700    1 AV  02/27/2021  15:00:00 2021-02-27 15:00:00  Saturday
# 32701    1 AV  02/27/2021  19:00:00 2021-02-27 19:00:00  Saturday
#
#                TURNSTILE  NET_ENTRIES  NET_EXITS  TRAFFIC  WEEKDAYS_INDEX
# 32697  H007AR24802-00-00          7.0        2.0      9.0               5
# 32698  H007AR24802-00-00         69.0        9.0     78.0               5
# 32699  H007AR24802-00-00        139.0       20.0    159.0               5
# 32700  H007AR24802-00-00        132.0       12.0    144.0               5
# 32701  H007AR24802-00-00         66.0       18.0     84.0               5

# %%
busiest_stations = df.groupby("STATION").sum().sort_values("TRAFFIC", ascending = False).reset_index().head(10)
busiest_stations.head(10)
# Out:
#            STATION  NET_ENTRIES  NET_EXITS    TRAFFIC  WEEKDAYS_INDEX
# 0   34 ST-PENN STA    2946280.0  3912956.0  6859236.0          142289
# 1  34 ST-HERALD SQ    2363386.0  3034560.0  5397946.0           79119
# 2            86 ST    2330395.0  2888176.0  5218571.0           87647
# 3           125 ST    2194129.0  2700668.0  4894797.0           60565
# 4   14 ST-UNION SQ    2091245.0  2721751.0  4812996.0           60071
# 5  GRD CNTRL-42 ST    2043347.0  2738372.0  4781719.0          103909
# 6            23 ST    2053302.0  2265066.0  4318368.0           95765
# 7  42 ST-PORT AUTH    1834617.0  2317176.0  4151793.0           61037
# 8    FLUSHING-MAIN    1833274.0  1998922.0  3832196.0           34072
# 9        FULTON ST    1637387.0  2052530.0  3689917.0          107436

# %%
plt.figure(figsize=(12,8),dpi=200)
plt.bar(busiest_stations.STATION, busiest_stations.TRAFFIC)
plt.xticks(rotation=45, ha='right');
plt.xlabel("STATIONS")
plt.ylabel("TOTAL TRAFFIC FOR LAST 3 MONTHS")
plt.title("TOP 10 BUSIEST STATIONS", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOP 10 BUSIEST STATIONS')

# %%
plt.figure(figsize=(12,8),dpi=200)
plt.barh(busiest_stations.STATION, busiest_stations.TRAFFIC, color=['blue', 'green', 'green', 'green', 'green','green','green','green','green','green']);
plt.gca().invert_yaxis()
plt.xlabel("TOTAL TRAFFIC")
plt.ylabel(" ")
plt.title("TOP 10 BUSIEST STATIONS", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOP 10 BUSIEST STATIONS')

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.set_style("whitegrid")
sns.barplot(y = 'STATION', x = 'TRAFFIC', data = busiest_stations)
plt.xlabel("TOTAL TRAFFIC")
plt.ylabel(" ")
plt.title("TOP 10 BUSIEST STATIONS", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOP 10 BUSIEST STATIONS')

# %%
busiest_days = df.groupby("WEEKDAYS").sum().sort_values("WEEKDAYS_INDEX", ascending = True).reset_index()
busiest_days
# Out:
#     WEEKDAYS  NET_ENTRIES   NET_EXITS     TRAFFIC  WEEKDAYS_INDEX
# 0     Monday   21594240.0  22460706.0  44054946.0               0
# 1    Tuesday   22925728.0  23899588.0  46825316.0          305428
# 2  Wednesday   22998561.0  23991296.0  46989857.0          611784
# 3   Thursday   23041643.0  24064991.0  47106634.0          918309
# 4     Friday   23213610.0  24560706.0  47774316.0         1210668
# 5   Saturday   15119151.0  17495008.0  32614159.0         1465275
# 6     Sunday   10922558.0  12928868.0  23851426.0         1715838

# %%
plt.figure(figsize=(12,8),dpi=200)
plt.bar(busiest_days.WEEKDAYS, busiest_days.TRAFFIC, color=['blue' if x < 40000000 else 'green' for x in busiest_days.TRAFFIC.values]);
plt.xlabel(" ")
plt.ylabel("TOTAL TRAFFIC")
plt.title("TOTAL TRAFFIC ACCORDING TO DAYS OF WEEK", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOTAL TRAFFIC ACCORDING TO DAYS OF WEEK')

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.set_style("whitegrid")
sns.barplot(x = 'WEEKDAYS', y = 'TRAFFIC', data = busiest_days)
plt.ylabel("TOTAL TRAFFIC")
plt.xlabel(" ")
plt.title("TOTAL TRAFFIC ACCORDING TO DAYS OF WEEK", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOTAL TRAFFIC ACCORDING TO DAYS OF WEEK')

# %%
busiest_times = df.groupby("TIME").sum().sort_values("TRAFFIC", ascending = False).reset_index()

for i in range(len(busiest_times)):
    
    if busiest_times['TIME'][i] < ('04:00:00'):
        busiest_times['TIME'][i] =  ('00:00 - 04:00')
    
    elif ('04:00:00') <= busiest_times['TIME'][i] < ('08:00:00'):
        busiest_times['TIME'][i] =  ('04:00 - 08:00')
    
    elif ('08:00:00') <= busiest_times['TIME'][i] < ('12:00:00'):
        busiest_times['TIME'][i] =  ('08:00 - 12:00')
    
    elif ('12:00:00') <= busiest_times['TIME'][i] < ('16:00:00'):
        busiest_times['TIME'][i] =  ('12:00 - 16:00')
    
    elif ('16:00:00') <= busiest_times['TIME'][i] < ('20:00:00'):
        busiest_times['TIME'][i] =  ('16:00 - 20:00')
    
    elif ('20:00:00') <= busiest_times['TIME'][i]:
        busiest_times['TIME'][i] =  ('20:00 - 00:00')
        
    i = i + 1

busiest_times
# Out:
# F:\ProgramFiles\Pyhton\anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# F:\ProgramFiles\Pyhton\anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# F:\ProgramFiles\Pyhton\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
busiest_times = busiest_times.groupby("TIME").sum().sort_values("TRAFFIC", ascending = False).reset_index()
busiest_times
# Out:
#             TIME  NET_ENTRIES   NET_EXITS     TRAFFIC  WEEKDAYS_INDEX
# 0  12:00 - 16:00   38257774.0  38204934.0  76462708.0         1118403
# 1  16:00 - 20:00   33955778.0  38954419.0  72910197.0         1110718
# 2  08:00 - 12:00   28435279.0  31513852.0  59949131.0         1105309
# 3  04:00 - 08:00   25845204.0  22478261.0  48323465.0         1056437
# 4  20:00 - 00:00   10762812.0  14825341.0  25588153.0         1040922
# 5  00:00 - 04:00    2558644.0   3424356.0   5983000.0          795513

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.set_style("whitegrid")

sns.barplot(x = 'TIME', y = 'TRAFFIC', data = busiest_times, order = ['00:00 - 04:00', '04:00 - 08:00', '08:00 - 12:00', '12:00 - 16:00', '16:00 - 20:00', '20:00 - 00:00'])
plt.xlabel(" ")
plt.ylabel("TOTAL TRAFFIC")
plt.title("TOTAL TRAFFIC ACCORDING TO TIMES OF DAY", family='serif',fontsize = 15,loc='center',color='r')
#plt.savefig(r"C:\Users\Fatih GÜLTÜRK\Desktop\MTA_görseller\Total_Traffic_AccTo_TımesOfDay.png", dpi=200)
# Out:
# Text(0.5, 1.0, 'TOTAL TRAFFIC ACCORDING TO TIMES OF DAY')

# %%
plt.figure(figsize=(12,8),dpi=200)
plt.pie(busiest_times.TRAFFIC,labels= busiest_times.TIME, autopct='%.0f%%', explode = [.1,0,0,0,0,0])
plt.title("TOTAL TRAFFIC ACCORDING TO TIMES OF DAY", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOTAL TRAFFIC ACCORDING TO TIMES OF DAY')

# %%
busiest_stations_weekdays = df.groupby(['STATION','WEEKDAYS',"WEEKDAYS_INDEX"]).agg({'TRAFFIC':'sum'}).reset_index()[["STATION","WEEKDAYS","TRAFFIC","WEEKDAYS_INDEX"]]
busiest_stations_weekdays
# Out:
#         STATION   WEEKDAYS   TRAFFIC  WEEKDAYS_INDEX
# 0          1 AV     Friday  253096.0               4
# 1          1 AV     Monday  217240.0               0
# 2          1 AV   Saturday  204802.0               5
# 3          1 AV     Sunday  147576.0               6
# 4          1 AV   Thursday  237798.0               3
# ...         ...        ...       ...             ...
# 2624  ZEREGA AV   Saturday   14961.0               5
# 2625  ZEREGA AV     Sunday   11632.0               6
# 2626  ZEREGA AV   Thursday   30256.0               3
# 2627  ZEREGA AV    Tuesday   30579.0               1
# 2628  ZEREGA AV  Wednesday   30641.0               2
#
# [2629 rows x 4 columns]

# %%
station1 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "34 ST-PENN STA" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station1
# Out:
#             STATION   WEEKDAYS    TRAFFIC  WEEKDAYS_INDEX
# 428  34 ST-PENN STA     Monday  1049779.0               0
# 432  34 ST-PENN STA    Tuesday  1093993.0               1
# 433  34 ST-PENN STA  Wednesday  1103489.0               2
# 431  34 ST-PENN STA   Thursday  1118661.0               3
# 427  34 ST-PENN STA     Friday  1138963.0               4
# 429  34 ST-PENN STA   Saturday   763596.0               5
# 430  34 ST-PENN STA     Sunday   590755.0               6

# %%
station2 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "34 ST-HERALD SQ" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station2
# Out:
#              STATION   WEEKDAYS   TRAFFIC  WEEKDAYS_INDEX
# 414  34 ST-HERALD SQ     Monday  812263.0               0
# 418  34 ST-HERALD SQ    Tuesday  867164.0               1
# 419  34 ST-HERALD SQ  Wednesday  870641.0               2
# 417  34 ST-HERALD SQ   Thursday  878747.0               3
# 413  34 ST-HERALD SQ     Friday  911031.0               4
# 415  34 ST-HERALD SQ   Saturday  622188.0               5
# 416  34 ST-HERALD SQ     Sunday  435912.0               6

# %%
station3 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "86 ST" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station3
# Out:
#     STATION   WEEKDAYS   TRAFFIC  WEEKDAYS_INDEX
# 771   86 ST     Monday  804894.0               0
# 775   86 ST    Tuesday  844033.0               1
# 776   86 ST  Wednesday  850130.0               2
# 774   86 ST   Thursday  867889.0               3
# 770   86 ST     Friday  866180.0               4
# 772   86 ST   Saturday  567154.0               5
# 773   86 ST     Sunday  418291.0               6

# %%
station4 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "125 ST" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station4
# Out:
#    STATION   WEEKDAYS   TRAFFIC  WEEKDAYS_INDEX
# 64  125 ST     Monday  737910.0               0
# 68  125 ST    Tuesday  780329.0               1
# 69  125 ST  Wednesday  768449.0               2
# 67  125 ST   Thursday  780422.0               3
# 63  125 ST     Friday  803403.0               4
# 65  125 ST   Saturday  584433.0               5
# 66  125 ST     Sunday  439851.0               6

# %%
station5 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "14 ST-UNION SQ" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station5
# Out:
#             STATION   WEEKDAYS   TRAFFIC  WEEKDAYS_INDEX
# 99   14 ST-UNION SQ     Monday  681676.0               0
# 103  14 ST-UNION SQ    Tuesday  741298.0               1
# 104  14 ST-UNION SQ  Wednesday  757414.0               2
# 102  14 ST-UNION SQ   Thursday  744309.0               3
# 98   14 ST-UNION SQ     Friday  805405.0               4
# 100  14 ST-UNION SQ   Saturday  650946.0               5
# 101  14 ST-UNION SQ     Sunday  431948.0               6

# %%
stations = [station1, station2, station3 ,station4 ,station5]
stations_for_tourists = pd.concat(stations)
stations_for_tourists
# Out:
#              STATION   WEEKDAYS    TRAFFIC  WEEKDAYS_INDEX
# 428   34 ST-PENN STA     Monday  1049779.0               0
# 432   34 ST-PENN STA    Tuesday  1093993.0               1
# 433   34 ST-PENN STA  Wednesday  1103489.0               2
# 431   34 ST-PENN STA   Thursday  1118661.0               3
# 427   34 ST-PENN STA     Friday  1138963.0               4
# 429   34 ST-PENN STA   Saturday   763596.0               5
# 430   34 ST-PENN STA     Sunday   590755.0               6
# 414  34 ST-HERALD SQ     Monday   812263.0               0
# 418  34 ST-HERALD SQ    Tuesday   867164.0               1
# 419  34 ST-HERALD SQ  Wednesday   870641.0               2
# 417  34 ST-HERALD SQ   Thursday   878747.0               3
# 413  34 ST-HERALD SQ     Friday   911031.0               4
# 415  34 ST-HERALD SQ   Saturday   622188.0               5
# 416  34 ST-HERALD SQ     Sunday   435912.0               6
# 771            86 ST     Monday   804894.0               0
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.lineplot(data=stations_for_tourists, x="WEEKDAYS", y="TRAFFIC", hue="STATION")

ax.axvspan("Friday", "Saturday", alpha=0.15, color='blue')

plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.title("TOTAL TRAFFIC OF TOP 5 STATIONS BY WEEKDAYS", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOTAL TRAFFIC OF TOP 5 STATIONS BY WEEKDAYS')

# %%
Most_Busiest_Station = df[df['STATION'] == '34 ST-PENN STA']
Most_Busiest_Station
# Out:
#                 STATION        DATE      TIME           TIMESTAMP  WEEKDAYS  \
# 55099    34 ST-PENN STA  02/27/2021  03:00:00 2021-02-27 03:00:00  Saturday
# 55100    34 ST-PENN STA  02/27/2021  07:00:00 2021-02-27 07:00:00  Saturday
# 55101    34 ST-PENN STA  02/27/2021  11:00:00 2021-02-27 11:00:00  Saturday
# 55102    34 ST-PENN STA  02/27/2021  15:00:00 2021-02-27 15:00:00  Saturday
# 55103    34 ST-PENN STA  02/27/2021  19:00:00 2021-02-27 19:00:00  Saturday
# ...                 ...         ...       ...                 ...       ...
# 2648989  34 ST-PENN STA  05/28/2021  02:00:00 2021-05-28 02:00:00    Friday
# 2648990  34 ST-PENN STA  05/28/2021  06:00:00 2021-05-28 06:00:00    Friday
# 2648991  34 ST-PENN STA  05/28/2021  10:00:00 2021-05-28 10:00:00    Friday
# 2648992  34 ST-PENN STA  05/28/2021  14:00:00 2021-05-28 14:00:00    Friday
# 2648993  34 ST-PENN STA  05/28/2021  18:00:00 2021-05-28 18:00:00    Friday
#
# ...

# %%
for i in range(len(Most_Busiest_Station['TIME'].index)):
    
    if Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] < ('04:00:00'):
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('00:00 - 04:00')
    
    elif ('04:00:00') <= Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] < ('08:00:00'):
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('04:00 - 08:00')
    
    elif ('08:00:00') <= Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] < ('12:00:00'):
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('08:00 - 12:00')
    
    elif ('12:00:00') <= Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] < ('16:00:00'):
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('12:00 - 16:00')
    
    elif ('16:00:00') <= Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] < ('20:00:00'):
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('16:00 - 20:00')
    
    elif ('20:00:00') <= Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]]:
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('20:00 - 00:00')
        
    i = i + 1
    
Most_Busiest_Station
# Out:
# F:\ProgramFiles\Pyhton\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# F:\ProgramFiles\Pyhton\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# F:\ProgramFiles\Pyhton\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
BT_of_MBS = Most_Busiest_Station.groupby(["TIME","WEEKDAYS","WEEKDAYS_INDEX"]).agg({'TRAFFIC':'sum'}).reset_index()[["TIME","WEEKDAYS","TRAFFIC","WEEKDAYS_INDEX"]]
BT_of_MBS
# Out:
#              TIME   WEEKDAYS   TRAFFIC  WEEKDAYS_INDEX
# 0   00:00 - 04:00     Friday   23747.0               4
# 1   00:00 - 04:00     Monday   21595.0               0
# 2   00:00 - 04:00   Saturday   18366.0               5
# 3   00:00 - 04:00     Sunday   13962.0               6
# 4   00:00 - 04:00   Thursday   24625.0               3
# 5   00:00 - 04:00    Tuesday   23813.0               1
# 6   00:00 - 04:00  Wednesday   24588.0               2
# 7   04:00 - 08:00     Friday  191438.0               4
# 8   04:00 - 08:00     Monday  217747.0               0
# 9   04:00 - 08:00   Saturday   76071.0               5
# 10  04:00 - 08:00     Sunday   50083.0               6
# 11  04:00 - 08:00   Thursday  215797.0               3
# 12  04:00 - 08:00    Tuesday  217663.0               1
# 13  04:00 - 08:00  Wednesday  214286.0               2
# 14  08:00 - 12:00     Friday  224900.0               4
# 15  08:00 - 12:00     Monday  203374.0               0
# ...

# %%
plt.figure(figsize=(12,8),dpi=200)

revels = BT_of_MBS.pivot("TIME", "WEEKDAYS_INDEX", "TRAFFIC")

revels.columns = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

ax = sns.heatmap(revels, linewidths=0.4, cmap="Reds")

ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
plt.xlabel(' ')
plt.ylabel(' ')

plt.title("BUSIEST DAYS AND TIMES FOR 34 ST-PENN STATION", family='serif',fontsize = 15,loc='center',color='Blue')
plt.show()
